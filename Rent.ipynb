# %%
class RentalCalculator:
    
    def __init__(self):
        self.rental = []
        self.laundry = []
        self.storage = []
        self.misc_income = []
        
        self.income_dict = {
        'rental income': self.rental,
        'laundry income': self.laundry,
        'storage income': self.storage,
        'misc income': self.misc_income}

        
        self.tax = []
        self.insurance = []
        self.hoa = []
        self.lawncare = []
        self.capex = []
        self.property = []
        self.mortgage = []
        self.gas = []
        self.water = []
        self.electricity = []
        self.sewage = []
        self.misc_expenses = []
        
        self.utilities_dict = {
        'gas expense': self.gas,
        'water expense': self.water,
        'electricity expense': self.electricity,
        'sewage expense': self.sewage,}
        
        self.utilities = sum(self.utilities_dict.values())
        self.down = []
        self.closing = []
        self.rehab = []
        self.misc_roi_cost = []
        
        self.expenses_dict = {
        'tax expense': self.tax,
        'insurance expense': self.insurance,
        'utilities expense': self.utilities,
        'hoa expense': self.hoa,
        'lawncare expense': self.lawncare,
        'capex expense': self.capex,
        'property management_expense': self.property,
        'mortgage expense': self.mortgage,
        'misc expense': self.misc_expenses}
        
        self.initial_costs = {
        'down payment': down_payment,
        'closing costs': closing_costs,
        'rehab costs': rehab_costs,
        'misc costs': misc_costs}
        
        self.total_investment = sum(self.initial_costs.values())

        
        self.total_expenses = sum(self.expenses.values())    
        self.annual_expenses = 12 * self.total_expenses
        
        self.total_income = (sum(income.values()))  
        self.annual_income = (12 * self.total_income)
        
        self.roi = (self.annual_cash_flow / self.total_investment) * 100
        self.perc_roi = str(round(self.roi, 2)) + "%"
        
        self.cash_flow = self.total_income - self.total_expenses
        self.annual_cash_flow = self.cash_flow * 12



    def incomeOptions(self):
        print(self.income_dict)
        income_action = input('Adjust/Return/Quit')
        if income_action.lower() == 'adjust':
            income_choice = input('Rental/Laundry/Storage/Misc')
            if income_choice.lower() == 'rental':
                self.rental = input('Input new value')
            elif income_choice.lower() == 'laundry':
                self.laundry = input('Input new value')
            elif income_choice.lower() == 'storage':
                self.storage = input('Input new value')
            elif income_choice.lower() == 'misc':
                self.misc_income = input('Input new value')
        
        
    def expenseOptions(self):
        print(self.expenses_dict)
        expenses_action = input('Adjust/Return/Quit')
        if expenses_action.lower() == 'adjust':
            expense_choice = input('Tax/Insurance/HOA/Lawncare/CapEx/Mortgage/Property Management/Utilities/Misc')
            if expense_choice.lower() == 'tax':
                self.tax = input('Input new value')
            elif expense_choice.lower() == 'insurance':
                self.insurance = input('Input new value')
            elif expense_choice.lower() == 'hoa':
                self.hoa = input('Input new value')
            elif expense_choice.lower() == 'lawncare':
                self.lawncare = input('Input new value')
            elif expense_choice.lower() == 'capex':
                self.capex = input('Input new value')
            elif expense_choice.lower() == 'mortgage':
                mortgage_expense = input('Input new value')
            elif expense_choice.lower() == 'property management':
                self.property = input('Input new value')
            elif expense_choice.lower() == 'misc':
                self.misc_expenses = input('Input new value')
            if expense_choice.lower() == 'utilities':
                print(self.utilities_list)
                utilities_choice = input('Electricity/Gas/Sewage/Water')
                if utilities_choice.lower() == 'gas':
                    self.gas = input('Input new value')
                elif utilities_choice.lower() == 'water':
                    self.water = input('Input new value')
                elif utilities_choice.lower() == 'electricity':
                    self.electricity = input('Input new value')
                elif utilities_choice.lower() == 'sewage':
                    self.sewage = input('Input new value')  
        
    
    def cashFlowOptions(self):
        print(f'Monthly: {str(self.cash_flow)}')
        print(f'Annual: {str(self.annual_cash_flow)}')
    
    def roiOptions(self):
        print(self.initial_costs)
        print(self.total_investment)
        print(self.perc_roi)
        roi_action = input('Adjust/Return/Quit')
        if roi_action.lower() == 'adjust':
            roi_choice = input('Down Payment/Closing/Rehab/Misc')
            if 'down' in roi_choice.lower():
                self.down = input('Input new value')
            if roi_choice.lower() == 'closing':
                self.closing = input('Input new value')
            if roi_choice.lower() == 'rehab':
                self.rehab = input('Input new value')
            if roi_choice.lower() == 'misc':
                self.misc_roi_cost = input('Input new value')

                
display = RentalCalculator()
while True:
    action = input('Income/Expenses/Cash Flow/ROI/Exit')
    
    if action.lower() == 'income':
        display.incomeOptions()
    elif action.lower() == 'expenses':
        display.expensesOptions()
    elif action.lower() == 'cash flow' or action.lower() == 'cashflow':
        display.cashFlowOptions()
    elif action.lower() == 'roi':
        display.roiOptions()
    elif action.lower() == 'exit':
        break
    elif action.lower() == 'return':
        continue
    else:
        print('Invalid action. Please try again.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 145>()
#     141             if roi_choice.lower() == 'misc':
#     142                 self.misc_roi_cost = input('Input new value')
# --> 145 display = RentalCalculator()
#     146 while True:
#     147     action = input('Income/Expenses/Cash Flow/ROI/Exit')
#
# Input In [24], in RentalCalculator.__init__(self)
#      27 self.misc_expenses = []
#      29 self.utilities_dict = {
#      30 'gas expense': self.gas,
#      31 'water expense': self.water,
#      32 'electricity expense': self.electricity,
#      33 'sewage expense': self.sewage,}
# ---> 35 self.utilities = sum(self.utilities_dict.values())
#      36 self.down = []
#      37 self.closing = []
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'
